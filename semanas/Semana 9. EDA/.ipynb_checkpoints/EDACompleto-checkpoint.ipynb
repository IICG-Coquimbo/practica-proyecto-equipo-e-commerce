# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, regexp_extract, when, lit, udf, regexp_replace
from pyspark.sql.types import FloatType, StringType, IntegerType
import re
# Cambiamos .get_session() por .getOrCreate()
spark = SparkSession.builder \
    .appName("EDA_Notebooks_Renato") \
    .config("spark.mongodb.read.connection.uri", "mongodb+srv://JavieraMorales:Javi28122004@cluster0.as1zz9d.mongodb.net/ecommerce.raw_data?retryWrites=true&w=majority") \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:10.3.0") \
    .getOrCreate()

# Carga de datos crudos desde Atlas
df_raw = spark.read.format("mongodb") \
    .option("database", "ecommerce") \
    .option("collection", "raw_data") \
    .load()

print("Datos cargados correctamente.")
# Out:
# Datos cargados correctamente.

# %%
print(df_raw.count())
# Out:
# 3623

# %% [markdown]
# # Limpieza de datos
# Filtramos nulos, vacíos y string con datos particulares

# %%
df_cleaned = df_raw.filter(
    (col("identificador").isNotNull()) & 
    (col("ram") != "") & 
    (col("marca") != "Sin ID") & 
    (col("precio") != "Sin nombre")
)

print(f"Total de registros después de limpiar los que no tienen identificador: {df_cleaned.count()}")
# Out:
# Total de registros después de limpiar los que no tienen identificador: 3613

# %% [markdown]
# # Extracción de datos de una columna

# %%
df_with_price = df_cleaned.withColumn(
    "precio_num", 
    regexp_replace(col("precio"), r"[\$\.\s]", "").cast(IntegerType())
)

df_with_price.select("identificador", "marca", "precio", "precio_num").show(5, truncate=False)
# Out:
# +--------------------------------------------------------------------------------+------+----------+----------+
# |identificador                                                                   |marca |precio    |precio_num|
# +--------------------------------------------------------------------------------+------+----------+----------+
# |Lenovo ThinkBook 16 Gen 9 (AMD Ryzen 7 250)                                     |Lenovo|1059992   |1059992   |
# |Notebook HP 14-dq2516la Intel Core i5 8 GB RAM 512 GB SSD                       |Hp    |350000    |350000    |
# |Apple MacBook Pro (Late 2020) con Apple Silicon M1 - 512 GB, Space Gray         |Apple |2020151292|2020151292|
# |Notebook HP 15-FD0273LA Intel Core i7 1355U 15.6" 16GB 512GB SSD Windows 11 Home|Hp    |699990    |699990    |
# |Acer Predator Helios Neo 16 AI PHN16-73-96XM-1                                  |Acer  |2699991   |2699991   |
# +--------------------------------------------------------------------------------+------+----------+----------+
# only showing top 5 rows

# %% [markdown]
# # Normalización numérica
#  Cambiamos la coma por punto y convertimos a Float para poder hacer clústeres

# %%
from pyspark.sql.functions import col, udf
from pyspark.sql.types import FloatType

def normalizar_float(valor):
    if not valor:
        return None
    try:
        return float(valor.replace(",", "."))
    except:
        return None

normalizar_udf = udf(normalizar_float, FloatType())

df_final = df_normalized.withColumn(
    "precio_final", 
    normalizar_udf(col("precio_raw_clean"))
).drop("precio_raw_clean")

df_final.select("identificador", "marca", "precio", "precio_final").show(5, truncate=False)
# Out:
# +---------------------------------------------------------------------------------------+------+-------+------------+
# |identificador                                                                          |marca |precio |precio_final|
# +---------------------------------------------------------------------------------------+------+-------+------------+
# |Lenovo ThinkBook 16 Gen 9 (AMD Ryzen 7 250)                                            |Lenovo|1059992|1059992.0   |
# |Notebook Dell Pro 16 PC16250 (DVRC5) – Rendimiento profesional y productividad avanzada|Dell  |1095386|1095386.0   |
# |HP ProBook 445 G10 (A1NF8LA) – Notebook Profesional de 14"                             |Hp    |789990 |789990.0    |
# |Apple MacBook Air 13" (Early 2026) con chip M5, 16 GB RAM y 512 GB SSD - Midnight      |Apple |1249990|1249990.0   |
# |Notebook HP ProBook 440 G11 – Potencia y Portabilidad para Profesionales               |Hp    |1078990|1078990.0   |
# +---------------------------------------------------------------------------------------+------+-------+------------+
# only showing top 5 rows

# %% [markdown]
# # Configuración de tipos de datos

# %%
df_normalized = df_cleaned.withColumn(
    "precio_raw_clean", 
    regexp_replace(col("precio"), r'[^\d,.]', "")
).withColumn(
    "precio_raw_clean", 
    regexp_replace(col("precio_raw_clean"), ",", ".")
)

# %%
# 2. Casteo de Variables (Normalización de Tipos)
df_final = df_normalized.select(
    col("identificador"),
    col("tienda"),
    col("marca"),
    col("ram"),
    col("procesador"),
    col("almacenamiento"),
    col("precio_raw_clean").cast(FloatType()).alias("precio_raw"),
    regexp_extract(col("ram"), r'(\d+)', 1).alias("ram_num_str")
)

df_final = df_final.withColumn(
    "ram_gbs", 
    col("ram_num_str").cast(IntegerType())
).drop("ram_num_str")

# %%
print("Previsualización de Datos Normalizados (Tipos Correctos):")
df_final.select("identificador", "precio_raw", "ram_gbs", "marca", "tienda").show(10, truncate=False)

# --- VERIFICACIÓN DE ESQUEMA ---
df_final.printSchema()
# Out:
# Previsualización de Datos Normalizados (Tipos Correctos):
# +-----------------------------------------------------------------------------------------+-----------+-------+--------+--------+
# |identificador                                                                            |precio_raw |ram_gbs|marca   |tienda  |
# +-----------------------------------------------------------------------------------------+-----------+-------+--------+--------+
# |Lenovo ThinkBook 16 Gen 9 (AMD Ryzen 7 250)                                              |1059992.0  |16     |Lenovo  |SoloTodo|
# |Notebook HP 14-dq2516la Intel Core i5 8 GB RAM 512 GB SSD                                |350000.0   |8      |Hp      |SoloTodo|
# |Apple MacBook Pro (Late 2020) con Apple Silicon M1 - 512 GB, Space Gray                  |2.0201513E9|512    |Apple   |SoloTodo|
# |Notebook HP 15-FD0273LA Intel Core i7 1355U 15.6" 16GB 512GB SSD Windows 11 Home         |699990.0   |16     |Hp      |SoloTodo|
# |Acer Predator Helios Neo 16 AI PHN16-73-96XM-1                                           |2699991.0  |32     |Acer    |SoloTodo|
# |ASUS VivoBook 15 OLED X1505VA-MA942W                                                     |719990.0   |8      |Asus    |SoloTodo|
# |Dell Inspiron 14 5440 (KCV5H / 16 GB RAM)                                                |676190.0   |16     |Dell    |SoloTodo|
# |Gigabyte Aero 16 XE4-73US918HP                                                           |1149990.0  |16     |Gigabyte|SoloTodo|
# |Dell Alienware 16 Area-51                                                                |2999900.0  |32     |Dell    |SoloTodo|
# |Notebook Lenovo IdeaPad Slim 5 Gen 10 - AMD Ryzen AI 7 350, 14" OLED, 24GB RAM, 512GB SSD|849990.0   |24     |Lenovo  |SoloTodo|
# +-----------------------------------------------------------------------------------------+-----------+-------+--------+--------+
# only showing top 10 rows
#
# root
#  |-- identificador: string (nullable = true)
#  |-- tienda: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- ram: string (nullable = true)
#  |-- procesador: string (nullable = true)
#  |-- almacenamiento: string (nullable = true)
#  |-- precio_raw: float (nullable = true)
#  |-- ram_gbs: integer (nullable = true)

# %%
from pyspark.sql.functions import col, when, concat, lit
df=df_final
# 1. Creación de la columna 'especialidad' basada en el contenido de 'formato_raw'
df_enriquecido = df.withColumn(
    "categoria",
    when(col("procesador").rlike("(?i)Ryzen 9|Core i9|M2 Max|M3 Max"), "Entusiasta / Ultra Alta Gama")
    .when(col("procesador").rlike("(?i)Ryzen 7|Core i7|M2 Pro|M3 Pro|Gamer"), "Gama Alta / Productividad")
    .when(col("procesador").rlike("(?i)Ryzen 5|Core i5|M1|M2|M3"), "Gama Media / Estándar")
    .when(col("procesador").rlike("(?i)Ryzen 3|Core i3|Celeron|Pentium|Athlon"), "Gama Entrada / Oficina")
    .otherwise("Otras Especificaciones")
)

# 2. Refinar el ID Único para diferenciar variantes del mismo SKU
# Esto combina Marca + Especialidad + SKU original para evitar colisiones
df_final = df_enriquecido.withColumn(
    "id_registro_unico",
    concat(col("marca"), lit("_"), col("categoria"), lit("_"), col("identificador"))
)

# 3. Mostrar los resultados para verificar la nueva columna
df_final.select(
    "identificador", 
    "marca", 
    "procesador",
    "categoria", 
    "precio_raw", 
    "id_registro_unico"
).show(10, truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------+--------+----------------------------------------------+-------------------------+-----------+-----------------------------------------------------------------------------------------------------------------------+
# |identificador                                                                            |marca   |procesador                                    |categoria                |precio_raw |id_registro_unico                                                                                                      |
# +-----------------------------------------------------------------------------------------+--------+----------------------------------------------+-------------------------+-----------+-----------------------------------------------------------------------------------------------------------------------+
# |Lenovo ThinkBook 16 Gen 9 (AMD Ryzen 7 250)                                              |Lenovo  |Ryzen 7                                       |Gama Alta / Productividad|1059992.0  |Lenovo_Gama Alta / Productividad_Lenovo ThinkBook 16 Gen 9 (AMD Ryzen 7 250)                                           |
# |Notebook HP 14-dq2516la Intel Core i5 8 GB RAM 512 GB SSD                                |Hp      |Intel Core i5                                 |Gama Media / Estándar    |350000.0   |Hp_Gama Media / Estándar_Notebook HP 14-dq2516la Intel Core i5 8 GB RAM 512 GB SSD                                     |
# |Apple MacBook Pro (Late 2020) con Apple Silicon M1 - 512 GB, Space Gray                  |Apple   |Apple M-Series M1 (3200 MHz)                  |Gama Media / Estándar    |2.0201513E9|Apple_Gama Media / Estándar_Apple MacBook Pro (Late 2020) con Apple Silicon M1 - 512 GB, Space Gray                    |
# |Notebook HP 15-FD0273LA Intel Core i7 1355U 15.6" 16GB 512GB SSD Windows 11 Home         |Hp      |Intel Core i7                                 |Gama Alta / Productividad|699990.0   |Hp_Gama Alta / Productividad_Notebook HP 15-FD0273LA Intel Core i7 1355U 15.6" 16GB 512GB SSD Windows 11 Home          |
# |Acer Predator Helios Neo 16 AI PHN16-73-96XM-1                                           |Acer    |Intel Core Ultra 9 275HX (2100 MHz - 5400 MHz)|Otras Especificaciones   |2699991.0  |Acer_Otras Especificaciones_Acer Predator Helios Neo 16 AI PHN16-73-96XM-1                                             |
# |ASUS VivoBook 15 OLED X1505VA-MA942W                                                     |Asus    |Intel Core i5-1335U (1300 MHz - 4600 MHz)     |Gama Media / Estándar    |719990.0   |Asus_Gama Media / Estándar_ASUS VivoBook 15 OLED X1505VA-MA942W                                                        |
# |Dell Inspiron 14 5440 (KCV5H / 16 GB RAM)                                                |Dell    |Intel Core i5-1334U (900 MHz - 4600 MHz)      |Gama Media / Estándar    |676190.0   |Dell_Gama Media / Estándar_Dell Inspiron 14 5440 (KCV5H / 16 GB RAM)                                                   |
# |Gigabyte Aero 16 XE4-73US918HP                                                           |Gigabyte|Intel Core i7-12700H (1700 MHz - 4700 MHz)    |Gama Alta / Productividad|1149990.0  |Gigabyte_Gama Alta / Productividad_Gigabyte Aero 16 XE4-73US918HP                                                      |
# |Dell Alienware 16 Area-51                                                                |Dell    |Intel Core Ultra 9 275HX (2100 MHz - 5400 MHz)|Otras Especificaciones   |2999900.0  |Dell_Otras Especificaciones_Dell Alienware 16 Area-51                                                                  |
# |Notebook Lenovo IdeaPad Slim 5 Gen 10 - AMD Ryzen AI 7 350, 14" OLED, 24GB RAM, 512GB SSD|Lenovo  |AMD Ryzen AI 7 350 (2000 MHz - 5000 MHz)      |Otras Especificaciones   |849990.0   |Lenovo_Otras Especificaciones_Notebook Lenovo IdeaPad Slim 5 Gen 10 - AMD Ryzen AI 7 350, 14" OLED, 24GB RAM, 512GB SSD|
# +-----------------------------------------------------------------------------------------+--------+----------------------------------------------+-------------------------+-----------+-----------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# # Convertir Columnas a categóricas

# %%
from pyspark.ml.feature import StringIndexer

# %% [markdown]
# 1. Configurar el Indexador para la columna 'marca'

# %%
# handleInvalid="keep" es una buena práctica para no romper el pipeline si aparece una marca nueva
indexer = StringIndexer(inputCol="marca", outputCol="marca_cat", handleInvalid="keep")

# %% [markdown]
# 2. Ajustar y transformar el DataFrame

# %%
from pyspark.ml import Pipeline
pipeline = Pipeline(stages=[indexer])
# Esto crea la nueva columna 'marca_cat' como un valor numérico (Double)
df_categorized = pipeline.fit(df_final).transform(df_final)
print("Columnas actuales en df_categorized:")
df_categorized.select("identificador", "marca", "marca_cat", "precio_raw", "ram_gbs").show(5, truncate=False)
# Out:
# Columnas actuales en df_categorized:
# +--------------------------------------------------------------------------------+------+---------+-----------+-------+
# |identificador                                                                   |marca |marca_cat|precio_raw |ram_gbs|
# +--------------------------------------------------------------------------------+------+---------+-----------+-------+
# |Lenovo ThinkBook 16 Gen 9 (AMD Ryzen 7 250)                                     |Lenovo|1.0      |1059992.0  |16     |
# |Notebook HP 14-dq2516la Intel Core i5 8 GB RAM 512 GB SSD                       |Hp    |0.0      |350000.0   |8      |
# |Apple MacBook Pro (Late 2020) con Apple Silicon M1 - 512 GB, Space Gray         |Apple |4.0      |2.0201513E9|512    |
# |Notebook HP 15-FD0273LA Intel Core i7 1355U 15.6" 16GB 512GB SSD Windows 11 Home|Hp    |0.0      |699990.0   |16     |
# |Acer Predator Helios Neo 16 AI PHN16-73-96XM-1                                  |Acer  |5.0      |2699991.0  |32     |
# +--------------------------------------------------------------------------------+------+---------+-----------+-------+
# only showing top 5 rows

# %% [markdown]
# 3. Limpieza final de columnas

# %%
# Convertimos marca_cat a Integer para mayor claridad en el esquema
df_final_clustering = df_categorized.withColumn("marca_cat", col("marca_cat").cast("int"))

# %%
# --- VERIFICACIÓN DE LOS DATOS ---
print(" Mapeo de Marcas a Categorías Numéricas:")
df_final_clustering.select("marca", "marca_cat").distinct().orderBy("marca_cat").show()

print(" Vista previa de los 10 registros listos para Clustering:")
df_final_clustering.select(
    "identificador", 
    "marca_cat", 
    "precio_raw", 
    "ram_gbs"
).show(10)
# Out:
#  Mapeo de Marcas a Categorías Numéricas:
# +-------------+---------+
# |        marca|marca_cat|
# +-------------+---------+
# |           Hp|        0|
# |       Lenovo|        1|
# |         Asus|        2|
# |         Dell|        3|
# |        Apple|        4|
# |         Acer|        5|
# |No disponible|        6|
# |      Generic|        7|
# |          Msi|        8|
# |      Lenovo®|        9|
# |        Asus®|       10|
# |             |       11|
# |      Samsung|       12|
# |          HP®|       13|
# |  Thunderobot|       14|
# |           Lg|       15|
# |       Apple®|       16|
# |     Gigabyte|       17|
# |    Microsoft|       18|
# |        Acer®|       19|
# +-------------+---------+
# only showing top 20 rows
#
#  Vista previa de los 10 registros listos para Clustering:
# +--------------------+---------+-----------+-------+
# |       identificador|marca_cat| precio_raw|ram_gbs|
# +--------------------+---------+-----------+-------+
# |Lenovo ThinkBook ...|        1|  1059992.0|     16|
# |Notebook HP 14-dq...|        0|   350000.0|      8|
# |Apple MacBook Pro...|        4|2.0201513E9|    512|
# |Notebook HP 15-FD...|        0|   699990.0|     16|
# |Acer Predator Hel...|        5|  2699991.0|     32|
# |ASUS VivoBook 15 ...|        2|   719990.0|      8|
# |Dell Inspiron 14 ...|        3|   676190.0|     16|
# |Gigabyte Aero 16 ...|       17|  1149990.0|     16|
# |Dell Alienware 16...|        3|  2999900.0|     32|
# |Notebook Lenovo I...|        1|   849990.0|     24|
# +--------------------+---------+-----------+-------+
# only showing top 10 rows

# %% [markdown]
# # EDA Completo

# %% [markdown]
# ## Paso 1: Análisis de Valores Faltantes

# %%
from pyspark.sql.functions import count, when, isnan, col
df_eda = df_final_clustering
# Conteo de nulos por columna
df_eda.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df_eda.columns]).show()
# Out:
# +-------------+------+-----+---+----------+--------------+----------+-------+---------+-----------------+---------+
# |identificador|tienda|marca|ram|procesador|almacenamiento|precio_raw|ram_gbs|categoria|id_registro_unico|marca_cat|
# +-------------+------+-----+---+----------+--------------+----------+-------+---------+-----------------+---------+
# |            0|     0|    0|  0|         0|             0|       605|    519|        0|                0|        0|
# +-------------+------+-----+---+----------+--------------+----------+-------+---------+-----------------+---------+

# %% [markdown]
# ## Paso 2. Estadísticas Descriptivas (Numéricas)

# %%
# Estadísticas para las variables cuantitativas
df_eda.select(
    "marca_cat", 
    "precio_raw", 
    "ram_gbs"
).describe().show()
# Out:
# +-------+------------------+--------------------+-----------------+
# |summary|         marca_cat|          precio_raw|          ram_gbs|
# +-------+------------------+--------------------+-----------------+
# |  count|              3613|                3008|             3094|
# |   mean|2.7068917796844727|1.098182643343935...|37.18681318681319|
# | stddev| 5.002230908580599|4.053171424066955E11|93.57331398187178|
# |    min|                 0|                 0.0|                0|
# |    max|                56|       1.62025617E13|             1605|
# +-------+------------------+--------------------+-----------------+

# %% [markdown]
# ## Estadísticas de Cardinalidad (Diversidad)

# %%
from pyspark.sql.functions import avg, stddev, count, round, col

df_eda.groupBy("marca_cat") \
    .agg(
        count("*").alias("N_Productos"),
        round(avg("precio_raw"), 2).alias("Avg_Precio"),
        round(stddev("precio_raw"), 2).alias("Desviacion_Precio")
    ) \
    .orderBy(col("Avg_Precio").desc()) \
    .show()
# Out:
# +---------+-----------+------------------+-------------------+
# |marca_cat|N_Productos|        Avg_Precio|  Desviacion_Precio|
# +---------+-----------+------------------+-------------------+
# |        8|         45|6.8818331538172E11|3.22786105222804E12|
# |        2|        615| 2.978495662266E10| 6.9467906801044E11|
# |        5|         89| 2.148192824867E10| 1.8540092818794E11|
# |        1|        828|     8.373741797E7|      2.065359669E9|
# |        4|        181|     2.772459958E7|     2.3082952227E8|
# |       27|          2|         1799990.0|                0.0|
# |       19|          4|         1729990.0|          608111.83|
# |       11|         28|        1694275.71|         1234110.38|
# |        9|         42|        1518799.52|          677496.12|
# |       20|          4|         1436128.5|          623145.27|
# |       10|         30|        1313656.67|          431576.77|
# |       13|         14|        1233561.43|           368585.8|
# |       34|          1|         1129990.0|               NULL|
# |       17|          5|         1118576.0|          717791.38|
# |       16|          5|         1117990.0|          180194.34|
# |        3|        484|        1008043.88|          587552.45|
# |        0|       1026|         813554.39|          997408.75|
# |       29|          2|          749990.0|                0.0|
# |       12|         26|         657179.23|         1031538.26|
# |       28|          2|          534995.0|          233338.17|
# +---------+-----------+------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ## Identificación de Valores Atípicos (Outliers)

# %%
#detectar datos que podrían ensuciar el modelo.
# Ver productos con precios sospechosamente bajos o altos
df_eda.filter((col("precio_raw") < 50000) | (col("precio_raw") > 4000000)).show()
# Out:
# +--------------------+-------------+-------+--------------------+--------------------+--------------+-------------+-------+--------------------+--------------------+---------+
# |       identificador|       tienda|  marca|                 ram|          procesador|almacenamiento|   precio_raw|ram_gbs|           categoria|   id_registro_unico|marca_cat|
# +--------------------+-------------+-------+--------------------+--------------------+--------------+-------------+-------+--------------------+--------------------+---------+
# |Apple MacBook Pro...|     SoloTodo|  Apple|              512 GB|Apple M-Series M1...|    SSD 512 GB|  2.0201513E9|    512|Gama Media / Está...|Apple_Gama Media ...|        4|
# |ASUS ROG Strix SC...|     SoloTodo|   Asus|64 GB DDR5 (5600 ...|Intel Core Ultra ...|      SSD 2 TB|    5049990.0|     64|Otras Especificac...|Asus_Otras Especi...|        2|
# |Acer Nitro V 16 A...|     SoloTodo|   Acer|16 GB DDR5 (4800 ...|AMD Ryzen 5 240 (...|    SSD 512 GB|1.61642303E12|     16|Gama Media / Está...|Acer_Gama Media /...|        5|
# |HP ZBook Fury G1i...|     SoloTodo|     Hp|64 GB DDR5 (5600 ...|Intel Core Ultra ...|      SSD 2 TB|    6004900.0|     64|Otras Especificac...|Hp_Otras Especifi...|        0|
# |MSI Katana 15 HX ...|     SoloTodo|    Msi|16 GB DDR5 (5600 ...|Intel Core i7-146...|    SSD 512 GB|1.51400114E13|     16|Gama Alta / Produ...|Msi_Gama Alta / P...|        8|
# |Apple MacBook Air...|     SoloTodo|  Apple|              512 GB|Apple M-Series M1...|    SSD 512 GB|  2.0201513E9|    512|Gama Media / Está...|Apple_Gama Media ...|        4|
# |Lenovo Legion 5 1...|     SoloTodo| Lenovo|16 GB DDR5 (5600 ...|Intel Core Ultra ...|    SSD 512 GB| 5.1510829E10|     16|Otras Especificac...|Lenovo_Otras Espe...|        1|
# |Notebook HP 15-FC...|     SoloTodo|     Hp|16 GB DDR4 (3200 ...|             Ryzen 7|      SSD 1 TB|  1.5003112E7|     16|Gama Alta / Produ...|Hp_Gama Alta / Pr...|        0|
# |MSI Vector 17 HX ...|     SoloTodo|    Msi|32 GB DDR5 (5600 ...|Intel Core Ultra ...|      SSD 1 TB|    4559990.0|     32|Otras Especificac...|Msi_Otras Especif...|        8|
# |Lenovo Legion 9i ...|     SoloTodo| Lenovo|64 GB DDR5 (5200 ...|Intel Core Ultra ...|      SSD 2 TB|    5199993.0|     64|Otras Especificac...|Lenovo_Otras Espe...|        1|
# |Notebook Samsung ...|Mercado Libre|Samsung|                 8gb| Intel Core i5 1335U|         512gb|       799.99|      8|Gama Media / Está...|Samsung_Gama Medi...|       12|
# |HP ZBook Fury G1i...|     SoloTodo|     Hp|32 GB DDR5 (5600 ...|Intel Core Ultra ...|      SSD 2 TB|    4127900.0|     32|Otras Especificac...|Hp_Otras Especifi...|        0|
# |Acer Predator Hel...|     SoloTodo|   Acer|16 GB DDR5 (6400 ...|Intel Core Ultra ...|      SSD 1 TB|1.61671905E10|     16|Otras Especificac...|Acer_Otras Especi...|        5|
# |Asus ROG Strix G1...|     SoloTodo|   Asus|16 GB DDR5 (5600 ...|AMD Ryzen 9 9955H...|      SSD 1 TB|1.62025617E13|     16|Entusiasta / Ultr...|Asus_Entusiasta /...|        2|
# |Notebook Hp 14-em...|Mercado Libre|     Hp|                 8gb|             Ryzen 3|         512gb|       499.99|      8|Gama Entrada / Of...|Hp_Gama Entrada /...|        0|
# |Notebook Hp 245 G...|Mercado Libre|     Hp|                 8gb|             Ryzen 5|        512 GB|       499.99|      8|Gama Media / Está...|Hp_Gama Media / E...|        0|
# |Notebook Hp 14-dq...|Mercado Libre|     Hp|                 4gb|   Intel Inside N150|        128 GB|      198.397|      4|Otras Especificac...|Hp_Otras Especifi...|        0|
# |Notebook Dell Ins...|Mercado Libre|   Dell|                 8gb| Intel Core i5 1330U|         512gb|       725.99|      8|Gama Media / Está...|Dell_Gama Media /...|        3|
# |Notebook Hp 245 G...|Mercado Libre|     Hp|                 8gb|AMD Ryzen 3 R3 7330U|         512gb|        459.9|      8|Gama Entrada / Of...|Hp_Gama Entrada /...|        0|
# |Notebook Hp 250 G...|Mercado Libre|     Hp|                16gb| Intel Core i7 1255U|         512gb|       769.99|     16|Gama Alta / Produ...|Hp_Gama Alta / Pr...|        0|
# +--------------------+-------------+-------+--------------------+--------------------+--------------+-------------+-------+--------------------+--------------------+---------+
# only showing top 20 rows

# %%
df_eda = df_eda.filter(col("precio_raw") < 5000000)
df_eda = df_eda.filter(col("ram_gbs") <= 64)

# %% [markdown]
# ## Paso 3. Conteo Global de Duplicados
# Un duplicado exacto es aquel donde toda la fila se repite.

# %%
total_registros = df_eda.count()
unicos_registros = df_eda.distinct().count()

print(f"Total de registros: {total_registros}")
print(f"Registros únicos: {unicos_registros}")
print(f"Registros duplicados totales: {total_registros - unicos_registros}")
# Out:
# Total de registros: 2460
# Registros únicos: 1965
# Registros duplicados totales: 495

# %% [markdown]
# ## Guardar el progreso (Checkpoint)

# %%
# Crear una vista temporal para usar SQL si prefieren
df_eda.createOrReplaceTempView("tabla_notebooks_clean")

# consultas SQL ORDER BY
spark.sql("""
    SELECT 
        marca, 
        ROUND(AVG(precio_raw), 2) as avg_precio 
    FROM tabla_notebooks_clean 
    GROUP BY marca 
    ORDER BY avg_precio DESC
""").show()
# Out:
# +--------+----------+
# |   marca|avg_precio|
# +--------+----------+
# |   Acer®|1876656.67|
# | Lenovo®| 1577990.0|
# |        |1551767.78|
# |Dynabook| 1524990.0|
# |     HP®| 1312990.0|
# |   Asus®|1162095.26|
# |   Apple|1159769.94|
# |  Apple®| 1147490.0|
# |   Dell®| 1129990.0|
# |Gigabyte| 1118576.0|
# |     Msi|1104155.16|
# |    Dell|1028831.12|
# |    Asus| 829503.82|
# |  Lenovo| 771197.02|
# | MacBook|  749990.0|
# |      Hp| 739960.92|
# | Samsung| 702498.88|
# |  Huawei|  534995.0|
# |    Acer| 470877.97|
# |Notebook|  434990.0|
# +--------+----------+
# only showing top 20 rows

# %%
# Consulta avanzada para ver Veracidad y Variedad de precios
spark.sql("""
    SELECT 
        marca, 
        ROUND(AVG(precio_raw), 2) as avg_precio,
        COUNT(*) as cantidad_productos
    FROM tabla_notebooks_clean 
    GROUP BY marca 
    ORDER BY marca ASC, avg_precio DESC
""").show(20, truncate=False)
print(type(df_eda))
# Out:
# +----------------------+----------+------------------+
# |marca                 |avg_precio|cantidad_productos|
# +----------------------+----------+------------------+
# |                      |1551767.78|27                |
# |APPLE                 |989.99    |1                 |
# |Acer                  |470877.97 |68                |
# |Acer®                 |1876656.67|3                 |
# |Ancel x431 hd camiones|659.0     |1                 |
# |Apple                 |1159769.94|126               |
# |Apple®                |1147490.0 |4                 |
# |Asus                  |829503.82 |501               |
# |Asus®                 |1162095.26|19                |
# |CHUWI                 |229990.0  |1                 |
# |Dell                  |1028831.12|399               |
# |Dell®                 |1129990.0 |1                 |
# |Dynabook              |1524990.0 |2                 |
# |Gigabyte              |1118576.0 |5                 |
# |HP                    |495.88    |3                 |
# |HP®                   |1312990.0 |10                |
# |Hp                    |739960.92 |695               |
# |Huawei                |534995.0  |2                 |
# |Hyundai               |289990.0  |1                 |
# |JS Logia              |350.0     |1                 |
# +----------------------+----------+------------------+
# only showing top 20 rows
#
# <class 'pyspark.sql.dataframe.DataFrame'>

# %% [markdown]
# # Analisís Descriptivo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
from pyspark.sql.functions import col
wr.filterwarnings('ignore')

# %%
# 1. Definimos las columnas numéricas que YA sabemos que tienes
# Así evitamos que Spark intente adivinarlas y falle
numerical_columns = ["precio_raw", "ram_gbs"]

# 2. Convertimos a Pandas (esto es lo que permite que sns y plt funcionen)
df_pd = df_eda.select(numerical_columns).toPandas()

# 3. Configuramos y mostramos todos los gráficos de una vez
sns.set_style("darkgrid")

plt.figure(figsize=(14, len(numerical_columns) * 4))

for idx, feature in enumerate(numerical_columns, 1):
    plt.subplot(len(numerical_columns), 1, idx)
    sns.histplot(df_pd[feature], kde=True, color="teal", bins=30)
    plt.title(f"Distribución de la variable: {feature}", fontsize=14)
    plt.xlabel(feature)
    plt.ylabel("Frecuencia")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Subir a mongo en un nuevo contenedor

# %%
from pyspark.sql import SparkSession

# 1. Detén la sesión anterior si es necesario
# spark.stop() 

# 2. Crea la nueva sesión con el paquete del conector
# Nota: La versión 10.x es la recomendada para Spark 3.x y MongoDB Atlas
spark = SparkSession.builder \
    .appName("PracticaRenatoV") \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:10.1.1") \
    .getOrCreate()

# Ahora sí, puedes ejecutar la subida
# Nota: En el conector 10.x, el formato cambió de "mongo" a "mongodb"
df_final.write \
    .format("mongodb") \
    .mode("overwrite") \
    .option("spark.mongodb.write.connection.uri", "mongodb+srv://JavieraMorales:Javi28122004@cluster0.as1zz9d.mongodb.net/ecommerce.PracticaRenatoVilla?retryWrites=true&w=majority") \
    .option("database", "ecommerce") \
    .option("collection", "PracticaRenatoVilla") \
    .save()

# %%
df_eda.write.mode("overwrite").parquet("/home/jovyan/work/semanas/Semana 9. EDA/datos_practica")
