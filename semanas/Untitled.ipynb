# %%
from pymongo import MongoClient

# 1. Conexión
client = MongoClient("mongodb+srv://JavieraMorales:Javi28122004@cluster0.as1zz9d.mongodb.net/ecommerce?retryWrites=true&w=majority")
db = client["ecommerce"]
coleccion = db["notebooks_con_clusters"]

# 2. Definimos el filtro: documentos que NO tienen el campo 'prediction'
filtro = {"prediction": {"$exists": False}}

# 3. Contamos cuántos se borrarían
cantidad_a_borrar = coleccion.count_documents(filtro)
print(f"ATENCIÓN: Se encontraron {cantidad_a_borrar} documentos que NO tienen 'prediction' y serán eliminados.")

# 4. Mostramos una muestra (los primeros 3) para verificar que son los que queremos
if cantidad_a_borrar > 0:
    print("\n--- Muestra de los documentos que se van a eliminar: ---")
    muestra = coleccion.find(filtro).limit(3)
    for doc in muestra:
        print(doc)
    
    # 5. Opcional: confirmación manual
    confirmacion = input("\n¿Estás segura de querer borrar estos documentos? (escribe 'si' para confirmar): ")
    if confirmacion.lower() == 'si':
        resultado = coleccion.delete_many(filtro)
        print(f"\n¡Éxito! Se han eliminado {resultado.deleted_count} documentos.")
    else:
        print("\nOperación cancelada. No se ha borrado nada.")
else:
    print("No hay documentos para borrar. La colección ya está limpia.")
# Out:
# ATENCIÓN: Se encontraron 3623 documentos que NO tienen 'prediction' y serán eliminados.
#
# --- Muestra de los documentos que se van a eliminar: ---
# {'_id': '6a19acf14bed8488d349ecb3', 'almacenamiento': 'SSD 512 GB', 'fecha_captura': '2026-05-02 15:54:33', 'grupo': 'comercio electrónico', 'identificador': 'Lenovo ThinkBook 16 Gen 9 (AMD Ryzen 7 250)', 'marca': 'Lenovo', 'precio': '1059992', 'precio_numerico': 1059992.0, 'procesador': 'Ryzen 7', 'ram': '16 GB DDR5 (5600 MHz)', 'sist_operativo': 'Microsoft Windows 11 Pro', 'tienda': 'SoloTodo'}
# ...
