# %% [markdown]
# # El Contexto Comercial y la Recuperación de Datos

# %%
from pyspark.sql import SparkSession

# 1. Aseguramos la sesión activa en el Kernel actual
spark = SparkSession.builder.appName("Storytelling_Final").getOrCreate()

# 2. Traemos los datos nativos persistidos en formato Parquet
ruta_datos = "/home/jovyan/work/semanas/Semana 9. EDA/datos_practica"
df_completos = spark.read.parquet(ruta_datos)

ruta_datos = "/home/jovyan/work/semanas/Semana 10/modelos/datos_etiquetados_kmeans"
df_historico = spark.read.parquet(ruta_datos)

# 3. Contamos cuántos registros totales logramos recuperar para el análisis
total_registros = df_historico.count()
print(f" ÉXITO: Conexión establecida. Hemos recuperado {total_registros} productos.")
# Out:
#  ÉXITO: Conexión establecida. Hemos recuperado 2424 productos.

# %%
# Convertimos los datos recuperados a Pandas y los guardamos en un CSV ligero
df_historico.toPandas().to_csv("/home/jovyan/work/semanas/Semana 15/datos_practica.csv", index=False)
print("¡Dataset completo (con RAM y Clústeres) exportado para Streamlit!")
# Out:
# ¡Dataset completo (con RAM y Clústeres) exportado para Streamlit!

# %% [markdown]
# # Acto 1: El Storytelling del EDA (El diagnóstico inicial)

# %% [markdown]
# ## Código para el Nivel 1: Estratégico

# %%
import pyspark.sql.functions as F

# Calculamos la participación de cada marca para el Director General
total_sku = df_completos.count()

kpi_estrategico = df_completos.groupBy("marca") \
    .agg(
        F.count("marca").alias("Cantidad_SKUs"),
        F.round((F.count("marca") / total_sku) * 100, 2).alias("Participacion_Porcentaje")
    ).orderBy(F.desc("Participacion_Porcentaje"))

print(" [KPI ESTRATÉGICO] - ESTRUCTURA DE PORTAFOLIO POR MARCA")
kpi_estrategico.show()
# Out:
#  [KPI ESTRATÉGICO] - ESTRUCTURA DE PORTAFOLIO POR MARCA
# +-------------+-------------+------------------------+
# |        marca|Cantidad_SKUs|Participacion_Porcentaje|
# +-------------+-------------+------------------------+
# |           Hp|          695|                   28.25|
# |         Asus|          501|                   20.37|
# |       Lenovo|          472|                   19.19|
# |         Dell|          399|                   16.22|
# |        Apple|          126|                    5.12|
# |         Acer|           68|                    2.76|
# |No disponible|           32|                     1.3|
# |             |           27|                     1.1|
# |      Lenovo®|           25|                    1.02|
# |        Asus®|           19|                    0.77|
# |          Msi|           19|                    0.77|
# |      Samsung|           18|                    0.73|
# |          HP®|           10|                    0.41|
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pyspark.sql.functions as F

# 2. Conversión a Pandas solo para graficar (Tomamos las top 15 marcas para evitar saturar el eje Y)
df_est_pandas = kpi_estrategico.toPandas().head(15)

# 3. Diseño del Gráfico Estratégico
plt.figure(figsize=(12, 7)) # Un poquito más de altura para dar aire entre barras
sns.set_theme(style="whitegrid")

# Creamos gráfico de barras horizontales
ax = sns.barplot(
    x="Participacion_Porcentaje", 
    y="marca", 
    data=df_est_pandas, 
    hue="marca",
    palette="Blues_r",
    legend=False        
)

for p in ax.patches:
    ax.annotate(f'{p.get_width():.1f}%', 
                (p.get_width() + 0.5, p.get_y() + p.get_height()/2), 
                va='center', ha='left', fontsize=11, fontweight='bold')

plt.title("VISTA ESTRATÉGICA: Concentración del Portafolio por Marca (Frecuencia: Mensual)", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Participación en el Catálogo (% del Total de SKUs)", fontsize=12)
plt.ylabel("Marca", fontsize=12)
plt.xlim(0, df_est_pandas["Participacion_Porcentaje"].max() + 5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Código para el Nivel 2: Táctico

# %%
# Analizamos la dispersión y bandas de precios por TIENDA para el Gerente Comercial
kpi_tactico_tienda = df_completos.groupBy("tienda") \
    .agg(
        F.round(F.min("precio_raw"), 2).alias("Precio_Minimo"),
        F.round(F.avg("precio_raw"), 2).alias("Precio_Promedio"),
        F.round(F.max("precio_raw"), 2).alias("Precio_Maximo"),
        F.round(F.stddev("precio_raw"), 2).alias("Desviacion_Estandar_Precios"),
        F.count("precio_raw").alias("Total_Productos")
    ).orderBy(F.desc("Desviacion_Estandar_Precios"))

print(" [KPI TÁCTICO] - DISPERSIÓN Y BANDAS DE PRECIOS POR TIENDA")
kpi_tactico_tienda.show(20)
# Out:
#  [KPI TÁCTICO] - DISPERSIÓN Y BANDAS DE PRECIOS POR TIENDA
# +----------------+-------------+---------------+-------------+---------------------------+---------------+
# |          tienda|Precio_Minimo|Precio_Promedio|Precio_Maximo|Desviacion_Estandar_Precios|Total_Productos|
# +----------------+-------------+---------------+-------------+---------------------------+---------------+
# |SoloTodo-Javiera|          0.0|     1446716.62|    4948808.0|                 1113476.23|             90|
# |    TodoClick.cl|          0.0|     1136526.87|    4781990.0|                  733708.83|            607|
# |        SoloTodo|       279.99|     1116425.41|    4559990.0|                  715172.84|            530|
# |      PC Factory|     879990.0|     1357073.33|    2629990.0|                  526560.56|             72|
# | NotebookStoreCL|     438990.0|     1072217.45|    1994990.0|                  330990.92|            510|
# ...

# %%
# 2. Conversión a Pandas (Usando el DataFrame de tiendas y tomando el Top 15)
df_tac_pandas = kpi_tactico_tienda.toPandas().head(15)

# 3. Diseño del Gráfico Táctico (Dispersión por Tienda)
plt.figure(figsize=(14, 7))

plt.vlines(x=df_tac_pandas['tienda'], ymin=df_tac_pandas['Precio_Minimo'], ymax=df_tac_pandas['Precio_Maximo'], 
           colors='gray', alpha=0.5, linewidth=2, label="Rango de Precios (Min a Max)")

plt.scatter(df_tac_pandas['tienda'], df_tac_pandas['Precio_Promedio'], color='navy', s=100, label="Precio Promedio", zorder=3)
plt.scatter(df_tac_pandas['tienda'], df_tac_pandas['Precio_Minimo'], color='green', marker='^', s=60, label="Precio Mínimo", zorder=3)
plt.scatter(df_tac_pandas['tienda'], df_tac_pandas['Precio_Maximo'], color='red', marker='v', s=60, label="Precio Máximo", zorder=3)

plt.title(" VISTA TÁCTICA: Dispersión y Bandas de Precios por Tienda (Frecuencia: Mensual)", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Tiendas / Sucursales", fontsize=12)
plt.ylabel("Precio Original ($)", fontsize=12)
plt.xticks(rotation=45)
plt.legend(loc="upper right", frameon=True)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Código para el Nivel 3: Operacional

# %%
# [KPI OPERATIVO] - Control de rangos de precio (Mínimo y Máximo) por Marca
kpi_operativo_marcas = df_completos.groupBy("marca") \
    .agg(
        F.round(F.min("precio_raw"), 2).alias("Precio_Minimo"),
        F.round(F.max("precio_raw"), 2).alias("Precio_Maximo")
    ).orderBy("marca")

print(" [KPI OPERATIVO] - PRECIOS MÍNIMOS Y MÁXIMOS POR MARCA")
kpi_operativo_marcas.show(20, truncate=False)
# Out:
#  [KPI OPERATIVO] - PRECIOS MÍNIMOS Y MÁXIMOS POR MARCA
# +----------------------+-------------+-------------+
# |marca                 |Precio_Minimo|Precio_Maximo|
# +----------------------+-------------+-------------+
# |                      |370990.0     |4076990.0    |
# |APPLE                 |989.99       |989.99       |
# |Acer                  |0.0          |2699991.0    |
# |Acer®                 |1499990.0    |2629990.0    |
# |Ancel x431 hd camiones|659.0        |659.0        |
# |Apple                 |0.0          |4948808.0    |
# |Apple®                |879990.0     |1289990.0    |
# |Asus                  |0.0          |4781990.0    |
# |Asus®                 |879990.0     |1499990.0    |
# |CHUWI                 |229990.0     |229990.0     |
# |Dell                  |0.0          |3075990.0    |
# |Dell®                 |1129990.0    |1129990.0    |
# |Dynabook              |1149990.0    |1899990.0    |
# |Gigabyte              |0.0          |1999000.0    |
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pyspark.sql.functions as F

# 1. Procesamiento en Spark: Calculamos min y max por marca directamente
kpi_operativo_marcas = df_completos.groupBy("marca") \
    .agg(
        F.round(F.min("precio_raw"), 2).alias("Precio_Minimo"),
        F.round(F.max("precio_raw"), 2).alias("Precio_Maximo")
    )
df_op_pandas = kpi_operativo_marcas.toPandas()

# 2. Diseño del Gráfico Operacional (Matriz de Control de Precios)
plt.figure(figsize=(12, 7))

# Graficamos todas las marcas en gris (Precio Mínimo vs Precio Máximo)
sns.scatterplot(
    x="Precio_Minimo", 
    y="Precio_Maximo", 
    data=df_op_pandas, 
    alpha=0.6, 
    s=80, 
    color="darkgray"
)

UMBRAL_MIN = 50000
UMBRAL_MAX = 1500000

zona_peligro = df_op_pandas[(df_op_pandas['Precio_Minimo'] < UMBRAL_MIN) & (df_op_pandas['Precio_Maximo'] > UMBRAL_MAX)]

sns.scatterplot(
    x="Precio_Minimo", 
    y="Precio_Maximo", 
    data=zona_peligro, 
    color="crimson", 
    s=120, 
    label=" ALERTAS CRÍTICAS (Revisar Consistencia de Precios)", 
    edgecolor="black", 
    linewidth=1.5
)

# Dibujamos las líneas de umbral operativo
plt.axvline(x=UMBRAL_MIN, color='red', linestyle='--', alpha=0.7, linewidth=1.5)
plt.axhline(y=UMBRAL_MAX, color='red', linestyle='--', alpha=0.7, linewidth=1.5)

# Textos para guiar al supervisor en los cuadrantes
plt.text(UMBRAL_MIN * 0.1, df_op_pandas['Precio_Maximo'].max() * 0.8, "ZONA DE RIESGO\n(Piso muy bajo y Techo muy alto)", color="red", weight="bold", fontsize=11)
plt.text(UMBRAL_MIN * 1.2, df_op_pandas['Precio_Maximo'].max() * 0.2, "ZONA CONTROLADA\n(Precios estables)", color="green", weight="bold", fontsize=11)

plt.title(" VISTA OPERACIONAL: Matriz de Control y Límites de Precio por Marca", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Precio Mínimo Registrado ($)", fontsize=12)
plt.ylabel("Precio Máximo Registrado ($)", fontsize=12)
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %%
# =====================================================================
# AJUSTE DIDÁCTICO: Definimos los techos y pisos operativos para las marcas
UMBRAL_MIN = 50000    # Alerta si el producto más barato es menor a esto
UMBRAL_MAX = 1500000  # Alerta si el producto más caro supera esto
# =====================================================================

# 4. Resaltamos las ALERTAS ROJAS con los nuevos umbrales económicos
zona_peligro = df_op_pandas[(df_op_pandas['Precio_Minimo'] < UMBRAL_MIN) & (df_op_pandas['Precio_Maximo'] > UMBRAL_MAX)]
ax.scatter(
    zona_peligro["Precio_Minimo"], 
    zona_peligro["Precio_Maximo"], 
    color="#D32F2F", 
    s=130, 
    label="🚨 ALERTAS CRÍTICAS (Precios Descontrolados)", 
    edgecolor="black", 
    linewidth=1.2,
    zorder=4
)

# Líneas de Umbral Operacional ajustadas a Precios
ax.axvline(x=UMBRAL_MIN, color='#C62828', linestyle='--', alpha=0.6, linewidth=2)
ax.axhline(y=UMBRAL_MAX, color='#C62828', linestyle='--', alpha=0.6, linewidth=2)

# Coloreado sutil de los fondos adaptado a los cuadrantes de precio
# Cuadrante peligro: Precio Mínimo bajo el umbral (izquierda) y Máximo sobre el umbral (arriba)
ax.axvspan(xmin=ax.get_xlim()[0], xmax=UMBRAL_MIN, ymin=UMBRAL_MAX/ax.get_ylim()[1], ymax=1.0, color='#FFEBEE', alpha=0.5, zorder=0)
# Cuadrante saludable: Precios mínimos aceptables (derecha) y máximos controlados (abajo)
ax.axvspan(xmin=UMBRAL_MIN, xmax=ax.get_xlim()[1], ymin=0, ymax=UMBRAL_MAX/ax.get_ylim()[1], color='#E8F5E9', alpha=0.4, zorder=0)

# Ajustamos la posición del texto en base a los límites del gráfico para que no se tape
ax.text(ax.get_xlim()[0] + (UMBRAL_MIN * 0.05), ax.get_ylim()[1] * 0.85, "🔴 ZONA DE RIESGO\n(Dispersión Excesiva)", color="#B71C1C", weight="bold", fontsize=11, zorder=5)
ax.text(UMBRAL_MIN + (UMBRAL_MIN * 0.2), ax.get_ylim()[1] * 0.15, "🟢 ZONA SALUDABLE\n(Precios Controlados)", color="#1B5E20", weight="bold", fontsize=11, zorder=5)
# Out:
# Text(60000.0, -37116.12300000001, '🟢 ZONA SALUDABLE\n(Precios Controlados)')

# %% [markdown]
# # Acto 2: El Descubrimiento del Mercado (Segmentación)

# %%
import pyspark.sql.functions as F

# 1. Agrupamos por la predicción del K-Means, contamos y calculamos el porcentaje del total
resumen_clusters = df_historico.groupBy("prediction") \
    .agg(
        F.count("prediction").alias("Cantidad_Productos"),
        F.round((F.count("prediction") / total_registros) * 100, 2).alias("Porcentaje_Mercado"),
        F.round(F.avg("precio"), 2).alias("Precio_Promedio"),      # Corregido a 'precio'
        F.round(F.avg("ram_gb"), 1).alias("RAM_Promedio")          # Corregido a 'ram_gb'
    ).orderBy("prediction")

# 2. Mostramos el resultado en pantalla para la clase
print("Tabla 1: Resumen del resultado del clúster")
resumen_clusters.show()
#Así es como Spark nos resume millones de datos en tres decisiones de negocio.
# Out:
# Tabla 1: Resumen del resultado del clúster
# +----------+------------------+------------------+---------------+------------+
# |prediction|Cantidad_Productos|Porcentaje_Mercado|Precio_Promedio|RAM_Promedio|
# +----------+------------------+------------------+---------------+------------+
# |         0|              1678|             69.22|       823797.7|        13.5|
# |         1|               644|             26.57|     1868479.31|        27.0|
# |         2|               102|              4.21|     1402337.54|        64.0|
# +----------+------------------+------------------+---------------+------------+

# %% [markdown]
# Si observamos la tabla 1. El Cluster 0 representa el 69.22% del mercado con un precio bajo (Gama baja de notebooks). El Cluster 2 tiene pocos varios productos productos (644) pero un precio altísimo (Gama Alta), mientras tanto el Cluster 2 presenta la menor concentración de productos (102) con una participación del 4.21% del mercado pero con una cantidad de ram altisima.
