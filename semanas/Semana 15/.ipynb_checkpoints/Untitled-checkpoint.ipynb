# %%
import pandas as pd
df_check = pd.read_csv("/home/jovyan/work/semanas/Semana 15/datos_hardware_dashboard.csv")
print(df_check.columns.tolist())
print(df_check.shape)
# Out:
# ['_id', 'almacenamiento', 'almacenamiento_numero', 'fecha_captura', 'grupo', 'identificador', 'marca', 'marca_idx', 'precio', 'precio_numerico', 'procesador', 'procesador_idx', 'ram', 'ram_numero', 'sist_operativo', 'sist_operativo_idx', 'tienda', 'tienda_idx', 'prediction']
# (2268, 19)

# %%
import pandas as pd
df_check = pd.read_csv("/home/jovyan/work/semanas/Semana 15/datos_hardware_dashboard.csv")
print('marca' in df_check.columns)  # Debe decir True
# Out:
# True
