# %% [markdown]
# ## Ticket Salida semana 13

# %% [markdown]
# ## Respuesta N1
#
# Los datos son el problema principal debido a que la falta de caracteristicas claves y uso de datos incorrectos afectan directamente en la predicción.
# En el caso de los notebook, con el mercado digital los valores fluctuan bastante en base a los componentes que este posee,
# si un notebook solo es evaluado con los datos de la RAM y el almacenamiento puede generar una confusión ya que un notebook con 16GB de Ram y 512GB SSD puede costar
# $1.200.000CLP y otro puede costar $800.000CLP, si no se toman las variables que puedan afectar directamente al precio (la mayor cantidad de variables sin ocasionar sesgo), puede generar
# un vacio de información para poder determinar el valor.

# %% [markdown]
# ## Respuesta N2
#
# Principalmente en alimentar con mas datos que sean de valor para la predicción. Principalemte yo considero que para que la predicción de los valores de un producto veterinario
# sea mas preciso es necesario incorporar el Costo de la materia prima,el origen del producto si es nacional o internacional, el costo logistico, el costo de la producción del producto,
# el segmento comercial (categoria usando dummys), principalmente datos que ofrezcan una mayor visión sobre lo que influye en el precio de los productos de veterinario, ya que si solo
# nos quedamos con unos cuantos datos estamos cometiendo un sesgo por variable omitida.
#
# En cuanto al comportamiento del algoritmo con nuestros datos, el arbol de decisión no presento un 100% este mostro un 99.10%, esto debido a las etiquetas que se usaron para ello.
# En el cuadro de regresión al intentar predecir solo por la ram y almacenamiento fracaso bastante en intentar predecir el precio de los notebook con estas variables,
# esto se justifica principalmente por el bajo R^2, que es de un 29.63%, explicando tan solo ese mismo porcentaje de la variación de los precios, el otro porcentaje
# restante con el algoritmo que tenemos queda totalmentea al aire o ignorado dentro de las variables que afectan en el precio.
# Ya y como ultimo punto el en el Error promedio del modelo se encuentra un valor de $535.780 lo cual es bastante alto para intentar predecir el precio, dentro de las categorias
# de los notebook un error de este tamaño no es uno al cual se le pueda confiar en su predicción. Asi que como conclusión si, este modelo de predicción con los datos que nosotros
# tenemos no es realmente viable por sesgo de variables omitidas.
