# %% [markdown]
# # El Contexto Comercial y la Recuperación de Datos

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, regexp_extract, when, lit, udf, regexp_replace
from pyspark.sql.types import FloatType, StringType, IntegerType
import re
# Cambiamos .get_session() por .getOrCreate()
spark = SparkSession.builder \
    .appName("EDA_Notebooks_Javiera") \
    .config("spark.mongodb.read.connection.uri", "mongodb+srv://JavieraMorales:Javi28122004@cluster0.as1zz9d.mongodb.net/ecommerce.processed_data?retryWrites=true&w=majority") \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:10.1.1") \
    .getOrCreate() # <--- Línea corregida get_session() es solo si ya se ha iniciado una sesión previa

# Carga de datos crudos desde Atlas
df = spark.read.format("mongodb") \
    .option("database", "ecommerce") \
    .option("collection", "processed_data") \
    .load()

# %%
# Convertimos los datos recuperados a Pandas y los guardamos en un CSV ligero
df_completos = df
df_completos.toPandas().to_csv("/home/jovyan/work/semanas/Semana 15/datos_notebooks_dashboard.csv", index=False)
print(f" ÉXITO: Conexión establecida. Hemos recuperado {total_registros} productos veterinarios del histórico.")
# Out:
# ¡Datos exportados listos para Streamlit!

# %% [markdown]
# # Acto 1: El Storytelling del EDA (El diagnóstico inicial)

# %% [markdown]
# ## Código para el Nivel 1: Estratégico

# %%
import pyspark.sql.functions as F

# Calculamos la participación de cada marca para el Director General
total_identificador = df_completos.count()

kpi_estrategico = df_completos.groupBy("marca") \
    .agg(
        F.count("marca").alias("Cantidad_notebooks_marca"),
        F.round((F.count("marca") / total_identificador) * 100, 2).alias("Porcentaje_participacion")
    ).orderBy(F.desc("Porcentaje_participacion"))

print(" [KPI ESTRATÉGICO] - ESTRUCTURA DE PORTAFOLIO POR PROVEEDOR")
kpi_estrategico.show()
# Out:
#  [KPI ESTRATÉGICO] - ESTRUCTURA DE PORTAFOLIO POR PROVEEDOR
# +-----------+------------------------+------------------------+
# |      marca|Cantidad_notebooks_marca|Porcentaje_participacion|
# +-----------+------------------------+------------------------+
# |         HP|                     691|                   30.47|
# |       Asus|                     494|                   21.78|
# |     Lenovo|                     455|                   20.06|
# |       Dell|                     364|                   16.05|
# |      Apple|                     121|                    5.34|
# |       Acer|                      64|                    2.82|
# |        MSI|                      25|                     1.1|
# |    Samsung|                      20|                    0.88|
# |Thunderobot|                      12|                    0.53|
# |         LG|                       6|                    0.26|
# |   Gigabyte|                       4|                    0.18|
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pyspark.sql.functions as F

# 2. Conversión a Pandas solo para graficar
df_est_pandas = kpi_estrategico.toPandas()

# 3. Diseño del Gráfico Estratégico
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# Creamos gráfico de barras horizontales
ax = sns.barplot(
    x="Porcentaje_participacion", 
    y="marca", 
    data=df_est_pandas, 
    hue="marca",         # <-- Mapeo explícito de color
    palette="Purples_r",
    legend=False         # <-- Ocultamos la leyenda redundante
)

# Añadimos las etiquetas de porcentaje al final de cada barra
for p in ax.patches:
    ax.annotate(f'{p.get_width():.2f}%', 
                (p.get_width() + 1, p.get_y() + p.get_height()/2), 
                va='center', ha='left', fontsize=11, fontweight='bold')

plt.title("VISTA ESTRATÉGICA: Concentración del Portafolio por Marca (Frecuencia: Mensual)", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Participación en el Catálogo (% del Total de identificadores)", fontsize=12)
plt.ylabel("Marca / Fabricante", fontsize=12)
plt.xlim(0, df_est_pandas["Porcentaje_participacion"].max() + 10) # Espacio para el texto
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Código para el Nivel 2: Táctico

# %%
# !pip install plotly
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 4.2 MB/s  0:00:02 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [plotly]2m1/2 [plotly]
# ...

# %%
import plotly.express as px  # <- SOLUCIÓN AL ERROR: Importamos la librería que faltaba
import plotly.io as pio
pio.renderers.default = "iframe"
# 1. Agrupamos y contamos en PySpark (eficiente en el clúster)
kpi_hardware_spark = df_completos.groupBy("ram_numero", "almacenamiento_numero") \
    .agg(F.count("*").alias("Cantidad_Modelos")) \
    .orderBy(F.desc("Cantidad_Modelos"))

kpi_hardware_spark.show()
# Out:
# +----------+---------------------+----------------+
# |ram_numero|almacenamiento_numero|Cantidad_Modelos|
# +----------+---------------------+----------------+
# |      16.0|                512.0|             705|
# |      32.0|               1024.0|             343|
# |      16.0|               1024.0|             314|
# |       8.0|                512.0|             300|
# |       8.0|                256.0|             172|
# |      64.0|               1024.0|              67|
# |      32.0|                512.0|              60|
# |      24.0|                512.0|              36|
# |      16.0|                256.0|              36|
# |      32.0|               2048.0|              32|
# |       4.0|                128.0|              25|
# |      24.0|               1024.0|              23|
# |      64.0|               2048.0|              21|
# |      64.0|                512.0|              19|
# |      16.0|               2048.0|              16|
# ...

# %%
# 2. Convertimos el resultado agrupado a Pandas para que Plotly pueda leerlo
kpi_hardware_pandas = kpi_hardware_spark.toPandas()

# 3. Definimos los filtros de las capacidades comunes en Chile
valores_ram_validos = [4.0, 8.0, 12.0, 16.0, 24.0, 32.0, 64.0]
valores_almacenamiento_validos = [128.0, 240.0, 256.0, 512.0, 1024.0, 2048.0]

# 4. Filtramos la matriz final en Pandas usando los paréntesis correctos
df_heatmap_final = kpi_hardware_pandas[
    (kpi_hardware_pandas['ram_numero'].isin(valores_ram_validos)) & 
    (kpi_hardware_pandas['almacenamiento_numero'].isin(valores_almacenamiento_validos))
]

# 5. Dibujamos el Heatmap usando el DataFrame correcto (df_heatmap_final)
fig = px.density_heatmap(
    df_heatmap_final,  # <- Usamos los datos ya procesados y convertidos
    x="almacenamiento_numero",
    y="ram_numero",
    z="Cantidad_Modelos",
    text_auto=True,
    labels={
        "almacenamiento_numero": "Capacidad Almacenamiento (GB)",
        "ram_numero": "Memoria RAM (GB)",
        "Cantidad_Modelos": "N° de Equipos"
    },
    color_continuous_scale="YlOrRd",
    title="VISTA TÁCTICA: Combinaciones de Hardware más Comunes (Frecuencia: Semanal)"
)

# Ajustes de visualización para que actúen como bloques ordenados
fig.update_layout(
    xaxis=dict(type='category'),
    yaxis=dict(type='category')
)

# Si estás dentro de Jupyter Lab, para ver el gráfico solo debes escribir:
fig.show()

# Si estás guardándolo para la app final de Streamlit, recuerda usar:
# st.plotly_chart(fig, use_container_width=True)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_26.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Código para el Nivel 3: Operacional

# %%
import streamlit as st
import pandas as pd
import plotly.express as px
from pyspark.sql import functions as F

# =====================================================================
# 1. PROCESAMIENTO EN PYSPARK (Cálculo de la Métrica y Concentración)
# =====================================================================

# A. Obtenemos el total de registros del mercado para calcular porcentajes de participación
total_registros_mercado = df_completos.count()

# B. Agrupamos por tienda, contamos y calculamos la participación porcentual en el clúster
kpi_canales_spark = df_completos.groupBy("tienda") \
    .agg(F.count("*").alias("Cantidad_notebooks_tienda")) \
    .withColumn("Participacion_Gondola_Pct", F.round((F.col("Cantidad_notebooks_tienda") / total_registros_mercado) * 100, 2)) \
    .orderBy(F.asc("Cantidad_notebooks_tienda"))

# C. Convertimos el resultado consolidado a Pandas (Muestra resumida de pocas filas, segura para Streamlit)
kpi_canales_df = kpi_canales_spark.toPandas()

kpi_canales_spark.show()
# Out:
# +---------------+-------------------------+-------------------------+
# |         tienda|Cantidad_notebooks_tienda|Participacion_Gondola_Pct|
# +---------------+-------------------------+-------------------------+
# |         WEI.CL|                        1|                     0.04|
# |    BESTMART.CL|                        1|                     0.04|
# |         ITSHOP|                        4|                     0.18|
# |     TECHNOHIVE|                        5|                     0.22|
# |        MOXI.CL|                        5|                     0.22|
# |       TECNOMAS|                        6|                     0.26|
# |         MYSHOP|                        8|                     0.35|
# |    SCGLOBAL.CL|                        8|                     0.35|
# |     TECHRELOAD|                        9|                      0.4|
# |       ZTECH.CL|                       13|                     0.57|
# ...

# %%
fig = px.bar(
    kpi_canales_df,
    x="Participacion_Gondola_Pct",
    y="tienda",
    orientation="h",                  # Forzamos la orientación horizontal
    text="Participacion_Gondola_Pct", # Muestra el porcentaje exacto al final de cada barra
    title="VISTA OPERATIVA: Distribución y Participación de Canales (% del Total de la Oferta Digital) Frecuencia:tiempo real",
    labels={
        "Participacion_Gondola_Pct": "Cuota de Góndola Digital (%)",
        "tienda": "Portal Competidor / Retailer"
    },
    color="Participacion_Gondola_Pct",
    color_continuous_scale="Purples"   
)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_38.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Acto 2: El Descubrimiento del Mercado (Segmentación)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("EDA_Notebooks_Javiera") \
    .config("spark.mongodb.read.connection.uri", "mongodb+srv://JavieraMorales:Javi28122004@cluster0.as1zz9d.mongodb.net/ecommerce.processed_data?retryWrites=true&w=majority") \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:10.1.1") \
    .getOrCreate() # <--- Línea corregida get_session() es solo si ya se ha iniciado una sesión previa

# Carga de datos crudos desde Atlas
df_historico = spark.read.format("mongodb") \
    .option("database", "ecommerce") \
    .option("collection", "notebooks_con_clusters") \
    .load()

# %%
from pyspark.sql import functions as F

df_limpio = df_historico.filter(F.col("prediction").isNotNull())\
                        .withColumn("precio_numerico", F.col("precio_numerico").cast("double"))

total_registros = df_limpio.count()

resumen_clusters = df_limpio.groupBy("prediction")\
        .agg(
            F.count("prediction").alias("Cantidad_productos"),
            F.round((F.count("prediction")/total_registros)*100,2).alias("Porcentaje_mercado"),
            F.round(F.avg("precio_numerico"),1).alias("Precio_promedio")
        ).orderBy("prediction")
resumen_clusters.show()
# Out:
# +----------+------------------+------------------+---------------+
# |prediction|Cantidad_productos|Porcentaje_mercado|Precio_promedio|
# +----------+------------------+------------------+---------------+
# |         0|               941|             41.49|       646242.3|
# |         1|               501|             22.09|      1833760.9|
# |         2|                41|              1.81|      3904429.1|
# |         3|               102|               4.5|      1387372.6|
# |         4|               683|             30.11|      1120754.0|
# +----------+------------------+------------------+---------------+

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# 1. Convertimos solo las columnas necesarias a un DataFrame de Pandas
# Usamos df_limpio porque ya tiene los nulos filtrados y el precio como número (double)
df_grafico = df_limpio.select("precio_numerico", "prediction").toPandas()

# 2. Configurar el tamaño y estilo del gráfico
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# 3. Crear el gráfico de dispersión (Scatter Plot)
ax = sns.scatterplot(
    data=df_grafico,
    x=df_grafico.index,          # Distribuye los productos en el eje X según su orden de fila
    y="precio_numerico",         # Coloca el precio en el eje Y
    hue="prediction",            # Separa y colorea por Cluster
    palette="tab10",         # Usa la paleta de morados que querías
    s=60,                        # Aumentamos un poco el tamaño de los puntos
    alpha=0.8,                   # Menos transparencia para que los colores sean más sólidos
    edgecolor="white",           # Agregamos borde blanco para que resalten al superponerse
    linewidth=0.2
)

# 4. Formatear el eje Y para que muestre el signo peso y separador de miles
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: f"${x:,.0f}".replace(",", ".")))

# 5. Títulos y etiquetas de los ejes
plt.title("Distribución de Precios y Separación por Cluster", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Cantidad de Productos", fontsize=12)
plt.ylabel("Precios", fontsize=12)

# 6. Mover la leyenda fuera del gráfico para que no tape los puntos
plt.legend(title="Clusters (Predicción)", bbox_to_anchor=(1.02, 1), loc='upper left')

# Mostrar el gráfico de manera limpia
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Análisis

# %% [markdown]
# Si observamos la tabla 1, el Cluster 0 representa el 41.49% (941 registros) del mercado con el promedio de precio más bajo ($646.242) representando dispositivos de bajo costo orientados a tareas domésticas básicas (gama de entrada). Seguido del Cluster 4 con 683 registros representando el 30.11% del mercado con un precio promedio de $1.120.754. Por otra parte, el Cluster 2 presenta la menor cantidad de productos (41) y el promedio de precios más alto ($3.904.429).
