# %%
Ticket Salida semana 13
R1: Son los datos, los algoritmos pueden estar muy bien hechos y aun asi encontrar patrones matematicos problematicos con los datos que se le entregan,
Datos basura son la principal fuente de errores, Generalmente los algoritmos no tienen la culpa de no poder predecir bien un precio
principalmente si le faltan variables fianncieras y datos importantes que se omitieron para lograr conseguir ese valor predicho en el mercado.

# %%
R2: Esto se soluciona en el mundo real principalmente entregando datos relevantes para la predicción,
Por ejemplo para la predicción de alimentos de mascotas o alimentos en general es tomar variables relevantes para su influencia en el precio, tales como:
1. Costo de producción
2. Logistica
3. Categorización
4. Precios sustitutos

Si bien en nuestro caso con los procesadores, tarjetas graficas, ram, puede ir variando el precio
si no se identifican bien estos factores que alteran el precio no se puede realizar una prediccion correcta de los precios de los notebooks.
